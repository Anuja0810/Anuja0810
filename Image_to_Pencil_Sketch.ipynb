# %% [markdown]
# <a href="https://colab.research.google.com/github/Anuja0810/Anuja0810/blob/main/Image_to_Pencil_Sketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Let's Grow More - Virtual Intenship Program (LGMVIP)- November 2021
#
# Anuja Sawarkar
#
# Beginner Level Task 2: Image to Pencil Sketch using Python

# %% [markdown]
# Import Libraries

# %%
import numpy as np
import pandas as pd
import cv2 as cv 
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from PIL import Image 
import matplotlib.pylab as plt

# %%
img = io.imread('/content/drive/MyDrive/v.jpg') 
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=480x484 at 0x7F7712944C50>

# %%
img1 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

Image.fromarray(img1).save('/content/drive/MyDrive/v.jpg')
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=480x484 at 0x7F7712925650>

# %% [markdown]
# ***Convert Image to a Pencil Sketch***
#
# Converting a photo to pencil sketch involves the following steps:

# %% [markdown]
# **Step 1: Convert to Grey Image**
#
# Using cvtColor function of OpenCV.

# %%
grey_img=cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
cv2_imshow(grey_img)
# Out:
# <PIL.Image.Image image mode=L size=480x484 at 0x7F7714A2A0D0>

# %% [markdown]
# **Step 2: Invert Image**
#
# Inverting the image can be done by either of the following methods

# %%
invert_img=cv2.bitwise_not(grey_img)
#invert_img=255-grey_img
cv2_imshow(invert_img)
# Out:
# <PIL.Image.Image image mode=L size=480x484 at 0x7F7712932A50>

# %% [markdown]
# **Step 3: Blur image**
#
# Apply Gaussian blur to the image. The second argument to the function is the kernel size, if should be a pair of odd numbers.
# Larger the kernel size, more blurred the image will be and it will lose its subtle features.
# For creating sketch, we require only the prominent features (contrasting edges) from the image.
# For small images, kernel size of (3,3), (5,5) etc. will be sufficient, whereas for larger images, small kernel size do not create any impact.
# Appropriate kernel size can be selected by trial and error method.

# %%
blur_img=cv2.GaussianBlur(invert_img, (111,111),0)
cv2_imshow(blur_img)
# Out:
# <PIL.Image.Image image mode=L size=480x484 at 0x7F77149A2150>

# %% [markdown]
# **Step 4: Invert Blurred Image**
#
# Repeat step 2

# %%
invblur_img=cv2.bitwise_not(blur_img)
cv2_imshow(invblur_img)
#invblur_img=255-blur_img
# Out:
# <PIL.Image.Image image mode=L size=480x484 at 0x7F77149A24D0>

# %% [markdown]
# **Step 5: Sketch**
#
# The sketch can be obtained by performing bit-wise division between the grayscale image and the inverted-blurred image.

# %%
sketch_img=cv2.divide(grey_img,invblur_img, scale=256.0)
cv2_imshow(sketch_img)
# Out:
# <PIL.Image.Image image mode=L size=480x484 at 0x7F770E294990>

# %% [markdown]
# **Original Image vs Sketch**
#
# We can display the original image and sketch side by side for comparison.

# %%
plt.figure(figsize=(14,8))
plt.subplot(1,2,1)
plt.title('Original image', size=18)
plt.imshow(img)
plt.axis('off')
plt.subplot(1,2,2)
plt.title('Sketch', size=18)
rgb_sketch=cv2.cvtColor(sketch_img, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_sketch)
plt.axis('off')
plt.show()

# %% [markdown]
# ***Thank You***
